# %% [markdown]
# # Halo semuanya, selamat datang di penugasan praktikum pertama

# %% [markdown]
# Biar ilmu yang didapat selama asistensi ini lebih diserap dengan baik, usahakan untuk mengerjakan penugasan di bawah secara individu dulu, kalaupun binggung selama pengerjaannya bisa cari jawaban di internet, setelah semua dikerjakan baru dilanjut benchmark ke temanmu. Selamat mengerjakan, semoga logika kodingannya berjalan !!!

# %%
import pandas as pd

# %% [markdown]
# **Referensi youtube untuk melihat pentingnya data**
#
# How data improves our lives? Let us count the ways (UN DESA)
#
# https://youtu.be/kVMFjhMRyOw?si=zoNhm_w6uJVpWEJ2
#
# Industry Bytes | How Data-Driven Strategies Enhance Marketing Performance for Digital Brands (ISB Executive Education)
#
# https://youtu.be/jOFzp9MMSfg?si=xmTm6eypZc3VdM25

# %% [markdown]
# ![ImportanceOfData.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Penugasan Basic Python

# %% [markdown]
# Kamu adalah seorang data scientist bernama Dr. Z yang bekerja di sebuah laboratorium riset. Hari ini, kamu diberi tugas untuk menganalisis data tentang populasi hewan di salah satu hutan tropis. Tapi ada satu masalah penting pada laboratoriummu yaitu beberapa alat analisis rusak, jadi kamu harus menggunakan Python untuk menyelesaikan tugas ini dari awal!

# %% [markdown]
# Sebelum mulai, kamu perlu impor modul yang akan sangat membantu kamu dalam pekerjaanmu yaitu modul **math** dan modul **random** [Zen of python]

# %%
# Impor modul yang diperlukan
import ________  # Untuk operasi matematika
import ________  # Untuk menghasilkan angka acak

print('import berhasil dilakukan')

# Hasil yang diharapkan: "import berhasil dilakukan"

# %% [markdown]
# Python sangat sensitif terhadap indentation (spasi di awal huruf baris selanjutnya). Perbaiki spasi tersebut dan panggil fungsi di bawah [White space formatting]

# %%
# Contoh white space formatting
def hitung_populasi(populasi_awal, pertumbuhan):
hasil = populasi_awal * pertumbuhan
return hasil

# Panggil fungsi di bawah ini
populasi = _____(100, 2)
print("Populasi akhir:", populasi)

# Hasil yang diharapkan: "Populasi akhir: 200"

# %% [markdown]
# Langkah selanjutnya, kamu perlu menghitung perkiraan perkembangan populasi hewan setelah beberapa tahun [Aritmetic]

# %%
# Hitung total populasi setelah 5 tahun
populasi_awal = 100
pertumbuhan_tahunan = 1.5
jumlah_tahun = 5

populasi_akhir = populasi_awal * (pertumbuhan_tahunan ** ________)
print("Populasi akhir setelah 5 tahun:", populasi_akhir)

# Hasil yang diharapkan: "Populasi akhir setelah 5 tahun: 759.375"

# %% [markdown]
# Untuk menyederhanakan pekerjaanmu pembuatan function memang dianjurkan. Buatlah function pada kode di bawah. [Function]

# %%
# Buat perhitungan populasi akhir menjadi function
def ______(______, ______, ______):
    return populasi_awal * (pertumbuhan ** tahun)

# Panggil fungsi, 100 merupakan populasi awal, 1.5 merupakan pertumbuhan, dan
# 5 merupakan tahun
hasil = hitung_populasi(100, 1.5, 5)
print("Populasi akhir:", hasil)

# Hasil yang diharapkan: "Populasi akhir: 759.375"

# %% [markdown]
# Setelah kamu berhitung, pastikan kamu memberikan pesan yang mudah dipahami kepada tim-mu [String]

# %%
# Format string untuk menampilkan variabel ke dalam string
populasi_akhir = 759
pesan = _"Populasi akhir setelah 5 tahun adalah {________}."
print(pesan)

# Hasil yang diharapkan: "Populasi akhir setelah 5 tahun adalah 759."

# %% [markdown]
# Terkadang, data yang ada menghasilkan jawaban tidak valid. Kamu perlu menangani permasalahan ini [Exception]

# %%
# Hapus angka 0 dan ganti dengan angka 10 dan isi blank
___:
    hasil = 100 / 0
    print("Hasil:", hasil)
______ ZeroDivisionError:
    print("Error: Pembagian dengan nol tidak diperbolehkan.")

# Hasil yang diharapkan: "Hasil: 10.0"

# %% [markdown]
# Data populasi hewan rupanya disimpan dalam bentuk list, kamu perlu memproses informasinya [Lists]

# %%
# Daftar populasi hewan
populasi_hewan = [100, 150, 200, 250]

# Hitung rata-rata populasi
rata_rata = ____(populasi_hewan) / ____(populasi_hewan)
print("Rata-rata populasi:", rata_rata)

# Hasil yang diharapkan: "Rata-rata populasi: 175.0"

# %% [markdown]
# Beberapa data tidak boleh diubah setelah dibuat. Gunakan tuple untuk menyimpan data ini. [Tuple]

# %%
# Data koordinat lokasi hewan
koordinat = _10.5, 20.3_

# Cetak koordinat
print(f"Lokasi hewan berada di koordinat {koordinat}.")

# Hasil yang diharapkan: "Lokasi hewan berada di koordinat (10.5, 20.3)."

# %% [markdown]
# Data tentang jenis hewan disimpan dalam dictionary. Kamu perlu menampilkan nilai-nilai tertentu dari dictionary ini. [Dictionary]

# %%
# Dictionary data hewan
data_hewan = {"harimau": 50, "monyet": 200, "burung": 300}

# Tampilkan jumlah harimau
jumlah_harimau = data_hewan[________]
print("Jumlah harimau:", jumlah_harimau)

# Hasil yang diharapkan: "Jumlah harimau: 50"

# %% [markdown]
# Untuk menghindari duplikasi data gunakan set.  [Sets]

# %%
# Daftar spesies hewan
spesies = {"harimau", "monyet", "burung", "harimau"}

# Hapus duplikat dan cetak spesies unik menggunakan function set
spesies_unik = ________
print("Spesies unik:", spesies_unik)

# Hasil yang diharapkan: "Spesies unik: {'harimau', 'monyet', 'burung'}"

# %% [markdown]
# Gunakan control flow untuk memutuskan apakah suatu spesies perlu dilindungi. [Control flow]

# %%
# Jumlah populasi
populasi = 40

# Tentukan apakah spesies perlu dilindungi
__ poulasi <= 50__
    print("Spesies ini perlu dilindungi.")
_____:
    print("Spesies ini aman.")

# Hasil yang diharapkan: "Spesies ini perlu dilindungi."

# %% [markdown]
# Gunakan truthiness untuk memeriksa apakah suatu data valid. [Truthiness]

# %%
# Data kosong
data = []

# Periksa apakah data kosong
if ________:
    print("Data valid.")
else:
    print("Data kosong.")

# Hasil yang diharapkan: "Data kosong."

# %% [markdown]
# Diberikan beberapa kalimat, hitung berapa banyak kata yang unik dalam setiap kalimat (tanpa menghitung pengulangan kata yang sama).
#
# **Input:**
#
# T (jumlah test case)
#
# T baris berikutnya adalah kalimat
#
# **Output:**
#
# Untuk setiap kalimat, cetak jumlah kata yang unik
#
# `Contoh:`
#
# `Input:`
#
# `2`
#
# `saya suka data dan saya suka python`
#
# `belajar python itu menyenangkan`
#
# `Output:`
#
# `5`
#
# `4`

# %%
from test import test_fill_missing_values

# %%
def fill_missing_values(df):
    return None

# %%
test_fill_missing_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 test_fill_missing_values()
#
# File d:\Coding\Python\python_labs\Praktikum_PAP\test.py:24, in test_fill_missing_values()
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# NameError: name 'fill_missing_values' is not defined
